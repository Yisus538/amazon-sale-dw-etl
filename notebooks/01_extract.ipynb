# %% [markdown]
# # 📥 01 — Extracción
# **Metodología HEFESTO — Paso 2.2: Análisis de Data Sources**
#
# Lee el CSV fuente, lo copia intacto a  y guarda un snapshot en .

# %% [markdown]
# ## ⚙️ Configuración inicial

# %%
import sys
import os

# Agregar src/ al path para importar los módulos
sys.path.insert(0, os.path.abspath(".."))

from src.extract import ejecutar_extraccion
import pandas as pd

# %% [markdown]
# ## 📂 Extracción del CSV
#
# Reemplazá  con la ruta real al archivo descargado de Kaggle.

# %%
# Ruta al CSV original (relativa o absoluta)
PATH_CSV = "../data/01_raw/Amazon_Sale_Report.csv"


df_raw = ejecutar_extraccion(PATH_CSV, path_config="../config/settings.yaml")
# Out:
# ...
# PASO 1: EXTRACCIÓN
# ...
# [EXTRACT] ✅ Archivo copiado a: data/01_raw/Amazon_Sale_Report.csv
# [EXTRACT] ✅ CSV leído: 128,975 filas | 24 columnas
# ---------------------------------------------------------------------------
# ArrowKeyError                             Traceback (most recent call last)
# Cell In[23], line 5
#       1 # Ruta al CSV original (relativa o absoluta)
#       2 PATH_CSV = "../data/01_raw/Amazon_Sale_Report.csv"
# ----> 5 df_raw = ejecutar_extraccion(PATH_CSV, path_config="../config/settings.yaml")
#
# File ~/Documents/Facultad/BD II/Proyecto/mi_proyecto_etl/src/extract.py:92, in ejecutar_extraccion(path_csv, path_config)
#      90 config = cargar_config(path_config)
#      91 df_raw = extraer_csv(path_csv, config)
# ---> 92 guardar_interim(df_raw, config)
#      94 print(f"\n[EXTRACT] Columnas: {list(df_raw.columns)}")
#      95 print(f"[EXTRACT] Tipos:\n{df_raw.dtypes}")
#
# ...

# %% [markdown]
# ## 🔍 Exploración inicial del dataset

# %%
print(f"Filas: {len(df_raw):,} | Columnas: {len(df_raw.columns)}")
df_raw.head()

# %%
# Tipos de datos
df_raw.dtypes

# %%
# Nulos por columna
df_raw.isnull().sum().sort_values(ascending=False)

# %%
# Valores únicos de columnas clave
print("Status:",   df_raw["Status"].unique())
print("Category:", df_raw["Category"].unique())
print("Size:",     df_raw["Size"].unique())
print("Fulfil:",   df_raw["Fulfilment"].unique())

# %%
# Rango de fechas
print("Fecha mín:", df_raw["Date"].min())
print("Fecha máx:", df_raw["Date"].max())

# %% [markdown]
# ## ✅ Resultado
#
# El CSV fue copiado a  y el snapshot fue guardado en .
#
# ▶️ Siguiente paso: corré
